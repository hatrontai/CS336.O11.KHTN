# %%
# !git clone https://github.com/salesforce/LAVIS
# Out:
# Cloning into 'LAVIS'...
# remote: Enumerating objects: 7746, done.
# remote: Counting objects: 100% (7746/7746), done.
# remote: Compressing objects: 100% (2536/2536), done.
# remote: Total 7746 (delta 5017), reused 7433 (delta 4977), pack-reused 0
# Receiving objects: 100% (7746/7746), 86.16 MiB | 30.79 MiB/s, done.
# Resolving deltas: 100% (5017/5017), done.

# %%
# %cd LAVIS
# Out:
# /kaggle/working/LAVIS

# %%
# %%writefile requirements.txt
# contexttimer
# decord
# diffusers<=0.16.0
# einops>=0.4.1
# fairscale==0.4.4
# ftfy
# iopath
# ipython
# omegaconf
# opencv-python-headless==4.5.5.64
# opendatasets
# packaging
# pandas
# plotly
# pre-commit
# pycocoevalcap
# pycocotools
# python-magic
# scikit-image
# sentencepiece
# spacy
# streamlit
# timm==0.4.12
# torch>=1.10.0
# torchvision
# tqdm
# transformers==4.33.2
# webdataset
# wheel
# torchaudio
# soundfile
# moviepy
# nltk
# peft
#
# easydict==1.9
# pyyaml_env_tag==0.1
# open3d
# h5py
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt -q

# %%
# %%writefile /kaggle/working/LAVIS/lavis/datasets/datasets/retrieval_datasets.py
"""
 Copyright (c) 2022, salesforce.com, inc.
 All rights reserved.
 SPDX-License-Identifier: BSD-3-Clause
 For full license text, see the LICENSE file in the repo root or https://opensource.org/licenses/BSD-3-Clause
"""

import os
from collections import OrderedDict

from lavis.datasets.datasets.base_dataset import BaseDataset
from PIL import Image


class __DisplMixin:
    def displ_item(self, index):
        sample, ann = self.__getitem__(index), self.annotation[index]
        visual_key = "image" if "image" in ann else "video"

        return OrderedDict(
            {
                "file": ann[visual_key],
                "caption": ann["caption"],
                visual_key: sample[visual_key],
            }
        )


class RetrievalDataset(BaseDataset, __DisplMixin):
    def __init__(self, vis_processor, text_processor, vis_root, ann_paths):
        """
        vis_root (string): Root directory of images (e.g. coco/images/)
        ann_root (string): directory to store the annotation file
        """
        super().__init__(vis_processor, text_processor, vis_root, ann_paths)

        self.img_ids = {}
        n = 0
        for ann in self.annotation:
            img_id = ann["image_id"]
            if img_id not in self.img_ids.keys():
                self.img_ids[img_id] = n
                n += 1

    def __getitem__(self, index):

        ann = self.annotation[index]

        image_path = os.path.join('/kaggle/working/', ann["image"])
        image = Image.open(image_path).convert("RGB")

        image = self.vis_processor(image)
        caption = self.text_processor(ann["caption"])

        return {
            "image": image,
            "text_input": caption,
            "image_id": self.img_ids[ann["image_id"]],
            "instance_id": ann["instance_id"],
        }


class RetrievalEvalDataset(BaseDataset, __DisplMixin):
    def __init__(self, vis_processor, text_processor, vis_root, ann_paths):
        """
        vis_root (string): Root directory of images (e.g. coco/images/)
        ann_root (string): directory to store the annotation file
        split (string): val or test
        """

        super().__init__(vis_processor, text_processor, vis_root, ann_paths)

        self.text = []
        self.image = []
        self.txt2img = {}
        self.img2txt = {}

        txt_id = 0
        for img_id, ann in enumerate(self.annotation):
            self.image.append(ann["image"])
            self.img2txt[img_id] = []
            for i, caption in enumerate(ann["caption"]):
                self.text.append(self.text_processor(caption))
                self.img2txt[img_id].append(txt_id)
                self.txt2img[txt_id] = img_id
                txt_id += 1

    def __getitem__(self, index):
        self.vis_root = '/kaggle/working/'
        image_path = os.path.join(self.vis_root, self.annotation[index]["image"])
        image = Image.open(image_path).convert("RGB")

        image = self.vis_processor(image)

        return {"image": image, "index": index}


class VideoRetrievalDataset(BaseDataset, __DisplMixin):
    def __init__(self, vis_processor, text_processor, vis_root, ann_paths):
        """
        vis_root (string): Root directory of videos.
        ann_root (string): directory to store the annotation file
        """
        super().__init__(vis_processor, text_processor, vis_root, ann_paths)

        self.img_ids = {}
        n = 0
        for ann in self.annotation:
            img_id = ann["video"]
            if img_id not in self.img_ids.keys():
                self.img_ids[img_id] = n
                n += 1

    def __getitem__(self, index):

        ann = self.annotation[index]

        vpath = os.path.join(self.vis_root, ann["video"])

        video = self.vis_processor(vpath)
        caption = self.text_processor(ann["caption"])

        # return image, caption, self.img_ids[ann['image_id']]
        return {
            "video": video,
            "text_input": caption,
            "image_id": self.img_ids[ann["video"]],
        }


class VideoRetrievalEvalDataset(BaseDataset, __DisplMixin):
    def __init__(self, vis_processor, text_processor, vis_root, ann_paths):
        """
        vis_root (string): Root directory of videos.
        ann_root (string): directory to store the annotation file
        split (string): val or test
        """

        super().__init__(vis_processor, text_processor, vis_root, ann_paths)

        self.text = []
        self.image = []
        self.txt2img = {}
        self.img2txt = {}

        txt_id = 0
        for img_id, ann in enumerate(self.annotation):
            self.image.append(ann["video"])
            self.img2txt[img_id] = []
            for i, caption in enumerate(ann["caption"]):
                self.text.append(self.text_processor(caption))
                self.img2txt[img_id].append(txt_id)
                self.txt2img[txt_id] = img_id
                txt_id += 1

    def __getitem__(self, index):
        ann = self.annotation[index]

        vpath = os.path.join(self.vis_root, ann["video"])
        video = self.vis_processor(vpath)

        return {"video": video, "index": index}
# Out:
# Overwriting /kaggle/working/LAVIS/lavis/datasets/datasets/retrieval_datasets.py

# %%
import os
os.mkdir('/kaggle/working/flickr30k-images/')

# %%
import shutil
import os

source_dir = '/kaggle/input/flickr-image-dataset/flickr30k_images/flickr30k_images/'
destination_dir = '/kaggle/working/flickr30k-images'

if not os.path.exists(destination_dir):
    os.makedirs(destination_dir)

for entry in os.scandir(source_dir):
    if entry.is_file():
        shutil.copy(entry.path, destination_dir)

# %%
# !python -m torch.distributed.run --nproc_per_node=1 evaluate.py --cfg-path lavis/projects/blip2/eval/ret_flickr_eval.yaml
# Out:
# 2024-02-03 17:39:17.460487: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-03 17:39:17.460581: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-03 17:39:17.586445: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# | distributed init (rank 0, world 1): env://
# Downloading https://storage.googleapis.com/sfr-vision-language-research/datasets/flickr30k_train.json to /export/home/.cache/lavis/flickr30k/annotations/train.json
# 100%|████████████████████████| 20671677/20671677 [00:00<00:00, 134432053.97it/s]
# Downloading https://storage.googleapis.com/sfr-vision-language-research/datasets/flickr30k_val.json to /export/home/.cache/lavis/flickr30k/annotations/val.json
# 100%|█████████████████████████████| 404171/404171 [00:00<00:00, 92644881.52it/s]
# Downloading https://storage.googleapis.com/sfr-vision-language-research/datasets/flickr30k_test.json to /export/home/.cache/lavis/flickr30k/annotations/test.json
# 100%|█████████████████████████████| 396858/396858 [00:00<00:00, 90528258.92it/s]
# vocab.txt: 100%|█████████████████████████████| 232k/232k [00:00<00:00, 3.39MB/s]
# tokenizer_config.json: 100%|██████████████████| 28.0/28.0 [00:00<00:00, 148kB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 3.14MB/s]
# 100%|███████████████████████████████████████| 1.89G/1.89G [00:06<00:00, 303MB/s]
# Position interpolate from 16x16 to 26x26
# model.safetensors: 100%|██████████████████████| 440M/440M [00:01<00:00, 358MB/s]
# 100%|███████████████████████████████████████| 4.37G/4.37G [00:41<00:00, 114MB/s]
# Evaluation:  [   0/1000]  eta: 0:17:07    time: 1.0275  data: 0.0011  max mem: 11807
# Evaluation:  [  50/1000]  eta: 0:12:01    time: 0.7646  data: 0.0000  max mem: 11807
# Evaluation:  [ 100/1000]  eta: 0:11:25    time: 0.7645  data: 0.0000  max mem: 11807
# Evaluation:  [ 150/1000]  eta: 0:10:48    time: 0.7641  data: 0.0000  max mem: 11807
# Evaluation:  [ 300/1000]  eta: 0:08:54    time: 0.7659  data: 0.0000  max mem: 11807
# Evaluation:  [ 400/1000]  eta: 0:07:39    time: 0.7665  data: 0.0000  max mem: 11807
# Evaluation:  [ 450/1000]  eta: 0:07:00    time: 0.7664  data: 0.0000  max mem: 11807
# Evaluation:  [ 500/1000]  eta: 0:06:22    time: 0.7651  data: 0.0000  max mem: 11807
# Evaluation:  [ 550/1000]  eta: 0:05:44    time: 0.7652  data: 0.0000  max mem: 11807
# Evaluation:  [ 600/1000]  eta: 0:05:06    time: 0.7669  data: 0.0000  max mem: 11807
# Evaluation:  [ 650/1000]  eta: 0:04:27    time: 0.7646  data: 0.0000  max mem: 11807
# Evaluation:  [ 700/1000]  eta: 0:03:49    time: 0.7643  data: 0.0000  max mem: 11807
# Evaluation:  [ 750/1000]  eta: 0:03:11    time: 0.7648  data: 0.0000  max mem: 11807
# Evaluation:  [ 800/1000]  eta: 0:02:33    time: 0.7651  data: 0.0000  max mem: 11807
# Evaluation:  [ 850/1000]  eta: 0:01:54    time: 0.7666  data: 0.0000  max mem: 11807
# Evaluation:  [ 900/1000]  eta: 0:01:16    time: 0.7655  data: 0.0000  max mem: 11807
# Evaluation:  [ 950/1000]  eta: 0:00:38    time: 0.7652  data: 0.0000  max mem: 11807
# Evaluation:  [ 999/1000]  eta: 0:00:00    time: 0.7661  data: 0.0000  max mem: 11807
# Evaluation: Total time: 0:12:45 (0.7653 s / it)
# Evaluation:  [   0/5000]  eta: 0:29:42    time: 0.3565  data: 0.0053  max mem: 11807
# Evaluation:  [  50/5000]  eta: 1:18:36    time: 0.9653  data: 0.0000  max mem: 11807
# Evaluation:  [ 100/5000]  eta: 1:18:20    time: 0.9649  data: 0.0000  max mem: 11807
# Evaluation:  [ 150/5000]  eta: 1:17:45    time: 0.9696  data: 0.0000  max mem: 11807
# Evaluation:  [ 200/5000]  eta: 1:17:01    time: 0.9628  data: 0.0000  max mem: 11807
# Evaluation:  [ 250/5000]  eta: 1:16:17    time: 0.9701  data: 0.0000  max mem: 11807
# Evaluation:  [ 300/5000]  eta: 1:15:32    time: 0.9688  data: 0.0000  max mem: 11807
# Evaluation:  [ 350/5000]  eta: 1:14:45    time: 0.9702  data: 0.0000  max mem: 11807
# Evaluation:  [ 400/5000]  eta: 1:13:57    time: 0.9694  data: 0.0000  max mem: 11807
# Evaluation:  [ 450/5000]  eta: 1:13:09    time: 0.9645  data: 0.0000  max mem: 11807
# Evaluation:  [ 500/5000]  eta: 1:12:22    time: 0.9669  data: 0.0000  max mem: 11807
# Evaluation:  [ 550/5000]  eta: 1:11:34    time: 0.9647  data: 0.0000  max mem: 11807
# Evaluation:  [ 600/5000]  eta: 1:10:47    time: 0.9716  data: 0.0000  max mem: 11807
# Evaluation:  [ 650/5000]  eta: 1:09:59    time: 0.9644  data: 0.0000  max mem: 11807
# Evaluation:  [ 700/5000]  eta: 1:09:12    time: 0.9709  data: 0.0000  max mem: 11807
# Evaluation:  [ 750/5000]  eta: 1:08:24    time: 0.9653  data: 0.0000  max mem: 11807
# Evaluation:  [ 800/5000]  eta: 1:07:37    time: 0.9678  data: 0.0000  max mem: 11807
# Evaluation:  [ 850/5000]  eta: 1:06:49    time: 0.9699  data: 0.0000  max mem: 11807
# Evaluation:  [ 900/5000]  eta: 1:06:01    time: 0.9703  data: 0.0000  max mem: 11807
# Evaluation:  [ 950/5000]  eta: 1:05:13    time: 0.9691  data: 0.0000  max mem: 11807
# Evaluation:  [1000/5000]  eta: 1:04:24    time: 0.9628  data: 0.0000  max mem: 11807
# Evaluation:  [1050/5000]  eta: 1:03:36    time: 0.9663  data: 0.0000  max mem: 11807
# Evaluation:  [1100/5000]  eta: 1:02:48    time: 0.9647  data: 0.0000  max mem: 11807
# Evaluation:  [1150/5000]  eta: 1:02:00    time: 0.9722  data: 0.0000  max mem: 11807
# Evaluation:  [1200/5000]  eta: 1:01:12    time: 0.9633  data: 0.0000  max mem: 11807
# Evaluation:  [1250/5000]  eta: 1:00:24    time: 0.9705  data: 0.0000  max mem: 11807
# Evaluation:  [1300/5000]  eta: 0:59:35    time: 0.9622  data: 0.0000  max mem: 11807
# Evaluation:  [1350/5000]  eta: 0:58:47    time: 0.9665  data: 0.0000  max mem: 11807
# Evaluation:  [1400/5000]  eta: 0:57:58    time: 0.9650  data: 0.0000  max mem: 11807
# Evaluation:  [1450/5000]  eta: 0:57:10    time: 0.9687  data: 0.0000  max mem: 11807
# Evaluation:  [1500/5000]  eta: 0:56:22    time: 0.9681  data: 0.0000  max mem: 11807
# Evaluation:  [1550/5000]  eta: 0:55:34    time: 0.9683  data: 0.0000  max mem: 11807
# Evaluation:  [1600/5000]  eta: 0:54:45    time: 0.9689  data: 0.0000  max mem: 11807
# Evaluation:  [1650/5000]  eta: 0:53:57    time: 0.9625  data: 0.0000  max mem: 11807
# Evaluation:  [1700/5000]  eta: 0:53:09    time: 0.9676  data: 0.0000  max mem: 11807
# Evaluation:  [1750/5000]  eta: 0:52:20    time: 0.9637  data: 0.0000  max mem: 11807
# Evaluation:  [1800/5000]  eta: 0:51:32    time: 0.9675  data: 0.0000  max mem: 11807
# Evaluation:  [1850/5000]  eta: 0:50:44    time: 0.9641  data: 0.0000  max mem: 11807
# Evaluation:  [1900/5000]  eta: 0:49:56    time: 0.9710  data: 0.0000  max mem: 11807
# Evaluation:  [1950/5000]  eta: 0:49:07    time: 0.9641  data: 0.0000  max mem: 11807
# Evaluation:  [2000/5000]  eta: 0:48:19    time: 0.9678  data: 0.0000  max mem: 11807
# Evaluation:  [2050/5000]  eta: 0:47:31    time: 0.9648  data: 0.0000  max mem: 11807
# Evaluation:  [2100/5000]  eta: 0:46:43    time: 0.9699  data: 0.0000  max mem: 11807
# Evaluation:  [2150/5000]  eta: 0:45:54    time: 0.9685  data: 0.0000  max mem: 11807
# Evaluation:  [2200/5000]  eta: 0:45:06    time: 0.9650  data: 0.0000  max mem: 11807
# Evaluation:  [2250/5000]  eta: 0:44:18    time: 0.9683  data: 0.0000  max mem: 11807
# Evaluation:  [2300/5000]  eta: 0:43:29    time: 0.9654  data: 0.0000  max mem: 11807
# Evaluation:  [2350/5000]  eta: 0:42:41    time: 0.9681  data: 0.0000  max mem: 11807
# Evaluation:  [2400/5000]  eta: 0:41:53    time: 0.9656  data: 0.0000  max mem: 11807
# Evaluation:  [2450/5000]  eta: 0:41:04    time: 0.9672  data: 0.0000  max mem: 11807
# Evaluation:  [2500/5000]  eta: 0:40:16    time: 0.9629  data: 0.0000  max mem: 11807
# Evaluation:  [2550/5000]  eta: 0:39:28    time: 0.9705  data: 0.0000  max mem: 11807
# Evaluation:  [2600/5000]  eta: 0:38:40    time: 0.9654  data: 0.0000  max mem: 11807
# Evaluation:  [2650/5000]  eta: 0:37:51    time: 0.9694  data: 0.0000  max mem: 11807
# Evaluation:  [2700/5000]  eta: 0:37:03    time: 0.9685  data: 0.0000  max mem: 11807
# Evaluation:  [2750/5000]  eta: 0:36:15    time: 0.9660  data: 0.0000  max mem: 11807
# Evaluation:  [2800/5000]  eta: 0:35:26    time: 0.9663  data: 0.0000  max mem: 11807
# Evaluation:  [2850/5000]  eta: 0:34:38    time: 0.9647  data: 0.0000  max mem: 11807
# Evaluation:  [2900/5000]  eta: 0:33:49    time: 0.9704  data: 0.0000  max mem: 11807
# Evaluation:  [2950/5000]  eta: 0:33:01    time: 0.9645  data: 0.0000  max mem: 11807
# Evaluation:  [3000/5000]  eta: 0:32:13    time: 0.9687  data: 0.0000  max mem: 11807
# Evaluation:  [3050/5000]  eta: 0:31:24    time: 0.9640  data: 0.0000  max mem: 11807
# Evaluation:  [3100/5000]  eta: 0:30:36    time: 0.9660  data: 0.0000  max mem: 11807
# Evaluation:  [3150/5000]  eta: 0:29:48    time: 0.9649  data: 0.0000  max mem: 11807
# Evaluation:  [3200/5000]  eta: 0:28:59    time: 0.9693  data: 0.0000  max mem: 11807
# Evaluation:  [3250/5000]  eta: 0:28:11    time: 0.9625  data: 0.0000  max mem: 11807
# Evaluation:  [3300/5000]  eta: 0:27:23    time: 0.9660  data: 0.0000  max mem: 11807
# Evaluation:  [3350/5000]  eta: 0:26:34    time: 0.9680  data: 0.0000  max mem: 11807
# Evaluation:  [3400/5000]  eta: 0:25:46    time: 0.9672  data: 0.0000  max mem: 11807
# Evaluation:  [3450/5000]  eta: 0:24:58    time: 0.9668  data: 0.0000  max mem: 11807
# Evaluation:  [3500/5000]  eta: 0:24:09    time: 0.9660  data: 0.0000  max mem: 11807
# Evaluation:  [3550/5000]  eta: 0:23:21    time: 0.9667  data: 0.0000  max mem: 11807
# Evaluation:  [3600/5000]  eta: 0:22:33    time: 0.9648  data: 0.0000  max mem: 11807
# Evaluation:  [3650/5000]  eta: 0:21:44    time: 0.9704  data: 0.0000  max mem: 11807
# Evaluation:  [3700/5000]  eta: 0:20:56    time: 0.9617  data: 0.0000  max mem: 11807
# Evaluation:  [3750/5000]  eta: 0:20:08    time: 0.9685  data: 0.0000  max mem: 11807
# Evaluation:  [3800/5000]  eta: 0:19:20    time: 0.9729  data: 0.0000  max mem: 11807
# Evaluation:  [3850/5000]  eta: 0:18:31    time: 0.9720  data: 0.0000  max mem: 11807
# Evaluation:  [3900/5000]  eta: 0:17:43    time: 0.9701  data: 0.0000  max mem: 11807
# Evaluation:  [3950/5000]  eta: 0:16:55    time: 0.9699  data: 0.0000  max mem: 11807
# Evaluation:  [4000/5000]  eta: 0:16:06    time: 0.9843  data: 0.0000  max mem: 11807
# Evaluation:  [4050/5000]  eta: 0:15:18    time: 0.9692  data: 0.0000  max mem: 11807
# Evaluation:  [4100/5000]  eta: 0:14:30    time: 0.9723  data: 0.0000  max mem: 11807
# Evaluation:  [4150/5000]  eta: 0:13:41    time: 0.9638  data: 0.0000  max mem: 11807
# Evaluation:  [4200/5000]  eta: 0:12:53    time: 0.9655  data: 0.0000  max mem: 11807
# Evaluation:  [4250/5000]  eta: 0:12:05    time: 0.9633  data: 0.0000  max mem: 11807
# Evaluation:  [4300/5000]  eta: 0:11:16    time: 0.9662  data: 0.0000  max mem: 11807
# Evaluation:  [4350/5000]  eta: 0:10:28    time: 0.9623  data: 0.0000  max mem: 11807
# Evaluation:  [4400/5000]  eta: 0:09:40    time: 0.9702  data: 0.0000  max mem: 11807
# Evaluation:  [4450/5000]  eta: 0:08:51    time: 0.9656  data: 0.0000  max mem: 11807
# Evaluation:  [4500/5000]  eta: 0:08:03    time: 0.9669  data: 0.0000  max mem: 11807
# Evaluation:  [4550/5000]  eta: 0:07:15    time: 0.9628  data: 0.0000  max mem: 11807
# Evaluation:  [4600/5000]  eta: 0:06:26    time: 0.9667  data: 0.0000  max mem: 11807
# Evaluation:  [4650/5000]  eta: 0:05:38    time: 0.9667  data: 0.0000  max mem: 11807
# Evaluation:  [4700/5000]  eta: 0:04:50    time: 0.9624  data: 0.0000  max mem: 11807
# Evaluation:  [4750/5000]  eta: 0:04:01    time: 0.9695  data: 0.0000  max mem: 11807
# Evaluation:  [4800/5000]  eta: 0:03:13    time: 0.9642  data: 0.0000  max mem: 11807
# Evaluation:  [4850/5000]  eta: 0:02:25    time: 0.9689  data: 0.0000  max mem: 11807
# Evaluation:  [4900/5000]  eta: 0:01:36    time: 0.9651  data: 0.0000  max mem: 11807
# Evaluation:  [4950/5000]  eta: 0:00:48    time: 0.9691  data: 0.0000  max mem: 11807
# Evaluation:  [4999/5000]  eta: 0:00:00    time: 0.9644  data: 0.0000  max mem: 11807
# Evaluation: Total time: 1:20:34 (0.9669 s / it)
